# %%
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
X,y = make_regression(n_samples=100, n_features= 1, n_informative=1,n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha = 10)

# %%
rr.fit(X,y)
# Out:
# Ridge(alpha=10)

# %%
print(rr.coef_)
print(rr.intercept_)
# Out:
# [24.9546267]
# -2.1269130035235735

# %%
rr1 = Ridge(alpha = 100)
rr1.fit(X,y)
# Out:
# Ridge(alpha=100)

# %%
print(rr1.coef_)
print(rr1.intercept_)
# Out:
# [12.93442104]
# -1.4248441496033308

# %%
plt.plot(X,y,"b.")
plt.plot(X,model.predict(X), color = "red", label = "aplha 0 ")
plt.plot(X,rr.predict(X), color = "green", label = "aplha 10 ")
plt.plot(X,rr1.predict(X), color = "black", label = "aplha 100 ")
plt.legend()
