# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes

# %%
X, y = load_diabetes(return_X_y=True)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

# %%
X_train ,X_test , y_train,  y_test = train_test_split(X,y,test_size=0.2, random_state=2)

# %%
reg = Ridge(alpha=10, solver="cholesky")

# %%
reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=10, solver='cholesky')

# %%
pred = reg.predict(X_test)
print(pred)
# Out:
# [151.88306661 160.16019825 149.94252963 140.66592972 170.6454992
#  169.11465298 138.05449548 140.91074807 134.93606903 159.00033772
#  156.265779   155.81477644 160.0040244  153.93127519 169.9634718
#  137.09391746 156.87692142 145.46034052 149.2025411  149.03133965
#  142.46971077 165.10795915 158.03850913 158.61384868 144.17427717
#  167.99800654 160.45744592 147.29782724 130.01641037 175.0939958
#  171.80731694 143.86159207 132.70854606 143.2043816  162.26792499
#  155.39272734 155.87839565 163.28000306 142.00087303 170.49862348
#  145.35353299 145.58677719 159.66056847 159.6914743  154.47930509
#  150.14896031 156.94289573 179.11539606 144.21699949 164.90866225
#  168.65065215 142.77316067 147.06994086 155.38640329 160.13459174
#  144.53495756 157.33738099 135.90158269 152.50228185 146.45256066
#  154.08444394 158.09886191 142.22832423 160.46968303 154.11816878
#  156.21112913 148.17287826 159.62269428 142.31239985 152.01539005
#  160.79001988 157.32867731 142.48170737 149.37287316 146.9725208
#  142.02185346 135.04686719 137.32683385 155.91583226 136.68818551
#  137.98760968 141.70136458 151.41050721 175.20052442 161.67526386
#  146.55646122 169.92912337 155.84873143 144.449574  ]

# %%
plt.plot(X_train,y_train, "b.")
plt.plot(pred)
